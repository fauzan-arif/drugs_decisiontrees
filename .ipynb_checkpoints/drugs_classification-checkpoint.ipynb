# %% [markdown]
# ### Importing relevant packages

# %%
# Importing the required packages 
import numpy as np 
import pandas as pd 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt 
import seaborn as sns
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing the dataset

# %%
df_drugs = pd.read_csv('drug200.csv')

# %%
df_drugs
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %% [markdown]
# ### Exploratory Data Analysis and Pre-processing

# %%
df_drugs.shape
# Out:
# (200, 6)

# %%
df_drugs.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %%
df_drugs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
sns.pairplot(data=df_drugs, hue='Drug')

# %%
# to check categorical values in the data set 
df_drugs.describe(include='O')
# Out:
#         Sex    BP Cholesterol   Drug
# count   200   200         200    200
# unique    2     3           2      5
# top       M  HIGH        HIGH  drugY
# freq    104    77         103     91

# %%
# We have 4 columns categorical columns and we will need to encode them, several ways to do it i.e one hot encoder, or label encoder

# %%
#initialize the encoder class
label_enc = LabelEncoder()

# %%
#iterating through each categorical column and encode it. 
cols_to_encode = ['Sex', 'BP', 'Cholesterol', 'Drug']
for col in cols_to_encode:
    df_drugs[col] = label_enc.fit_transform(df_drugs[col])
df_drugs
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0     23    0   0            0   25.355     4
# 1     47    1   1            0   13.093     2
# 2     47    1   1            0   10.114     2
# 3     28    0   2            0    7.798     3
# 4     61    0   1            0   18.043     4
# ..   ...  ...  ..          ...      ...   ...
# 195   56    0   1            0   11.567     2
# 196   16    1   1            0   12.006     2
# 197   52    1   2            0    9.894     3
# 198   23    1   2            1   14.020     3
# 199   40    0   1            1   11.349     3
#
# [200 rows x 6 columns]

# %% [markdown]
# ### Modelling and Model Evaluation

# %%
#Lets seperate the features and target variable 
X = df_drugs.drop(columns = 'Drug')
Y = df_drugs['Drug']

# %%
#Split the data intro train , test split 
X_train, X_test, y_train, y_test = train_test_split(  
    X, Y, test_size = 0.3, random_state = 100)

# %%
#initialize the decision tree using both entropy and gini metrics 
clf_gini = DecisionTreeClassifier(criterion = "gini")
clf_entropy = DecisionTreeClassifier(criterion = "entropy")

# %%
#fitting the model using gini metric on features and target
clf_gini.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#fitting the model using entropy on features and target
clf_entropy.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
#predicting the target and then evaluating the performance using classification repport
y_pred_gini = clf_gini.predict(X_test)
report_gini = classification_report(y_test, y_pred_gini)
print(report_gini)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         5
#            3       1.00      0.92      0.96        13
#            4       0.97      1.00      0.98        31
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.98      0.99        60
# weighted avg       0.98      0.98      0.98        60

# %%
##predicting the target and then evaluating the performance using classification repport
y_pred_entropy = clf_entropy.predict(X_test)
report_entropy = classification_report(y_test, y_pred_entropy)
print(report_entropy)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         5
#            3       1.00      0.92      0.96        13
#            4       0.97      1.00      0.98        31
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.98      0.99        60
# weighted avg       0.98      0.98      0.98        60

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 8), dpi=200)
plot_tree(clf_gini, feature_names=df_drugs.columns, filled=True)
# Out:
# [Text(0.625, 0.9, 'Na_to_K <= 14.588\ngini = 0.701\nsamples = 140\nvalue = [20, 8, 11, 41, 60]'),
#  Text(0.5, 0.7, 'BP <= 0.5\ngini = 0.646\nsamples = 80\nvalue = [20, 8, 11, 41, 0]'),
#  Text(0.25, 0.5, 'Age <= 50.5\ngini = 0.408\nsamples = 28\nvalue = [20, 8, 0, 0, 0]'),
#  Text(0.125, 0.3, 'gini = 0.0\nsamples = 20\nvalue = [20, 0, 0, 0, 0]'),
#  Text(0.375, 0.3, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0]'),
#  Text(0.75, 0.5, 'BP <= 1.5\ngini = 0.334\nsamples = 52\nvalue = [0, 0, 11, 41, 0]'),
#  Text(0.625, 0.3, 'Cholesterol <= 0.5\ngini = 0.497\nsamples = 24\nvalue = [0, 0, 11, 13, 0]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0]'),
#  Text(0.75, 0.1, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0]'),
#  Text(0.875, 0.3, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 0, 28, 0]'),
#  Text(0.75, 0.7, 'gini = 0.0\nsamples = 60\nvalue = [0, 0, 0, 0, 60]')]

# %%
plot_tree(clf_entropy, feature_names=df_drugs.columns, filled=True)
# Out:
# [Text(0.625, 0.9, 'Na_to_K <= 14.588\nentropy = 1.968\nsamples = 140\nvalue = [20, 8, 11, 41, 60]'),
#  Text(0.5, 0.7, 'BP <= 0.5\nentropy = 1.72\nsamples = 80\nvalue = [20, 8, 11, 41, 0]'),
#  Text(0.25, 0.5, 'Age <= 50.5\nentropy = 0.863\nsamples = 28\nvalue = [20, 8, 0, 0, 0]'),
#  Text(0.125, 0.3, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0, 0, 0, 0]'),
#  Text(0.375, 0.3, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0]'),
#  Text(0.75, 0.5, 'BP <= 1.5\nentropy = 0.744\nsamples = 52\nvalue = [0, 0, 11, 41, 0]'),
#  Text(0.625, 0.3, 'Cholesterol <= 0.5\nentropy = 0.995\nsamples = 24\nvalue = [0, 0, 11, 13, 0]'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0]'),
#  Text(0.75, 0.1, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0]'),
#  Text(0.875, 0.3, 'entropy = 0.0\nsamples = 28\nvalue = [0, 0, 0, 28, 0]'),
#  Text(0.75, 0.7, 'entropy = 0.0\nsamples = 60\nvalue = [0, 0, 0, 0, 60]')]
